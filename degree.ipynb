# %%
import argparse
import collections
import matplotlib.pylab as pl
# %matplotlib inline
import networkx as nx
import my
# Out:
# /home/gaiyu/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
args = argparse.Namespace()
args.graph_tuple = ('soc-Epinions1', 'soc-Slashdot0811', 'soc-Slashdot0902')

# %%
deg_dict = collections.OrderedDict()
for key in args.graph_tuple:
    g = my.read_edgelist('data/' + key, fill=True)
    adj = nx.adj_matrix(g)
    deg_dict[key] = adj.sum(1)

# %%
for key, deg in deg_dict.items():
    pl.figure()
    pl.hist(deg, bins=1000, histtype='step')
    
    pl.title(key)
    pl.xlabel('degree')
    pl.ylabel('count')
    pl.xscale('log')
    pl.yscale('log')
